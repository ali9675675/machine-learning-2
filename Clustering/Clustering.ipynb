# %% [markdown]
# # Basics of cluster analysis

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('002 3.01.Country-clusters[UdemyIran.Com].csv')
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Select the features

# %%
x = data.iloc[:, 1:3]

# %%
x
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40
# 5    -25.45     133.11

# %% [markdown]
# ## Clustring

# %%
kmeans = KMeans(3)

# %%
kmeans.fit(x)
# Out:
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([0, 0, 1, 1, 1, 2], dtype=int32)

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#      Country  Latitude  Longitude Language  Cluster
# 0        USA     44.97    -103.77  English        0
# 1     Canada     62.40     -96.80  English        0
# 2     France     46.75       2.40   French        1
# 3         UK     54.01      -2.53  English        1
# 4    Germany     51.15      10.40   German        1
# 5  Australia    -25.45     133.11  English        2

# %%
plt.scatter(data_with_clusters['Longitude'], data_with_clusters['Latitude'], c=data_with_clusters['Cluster'], cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Map the data

# %%
data_mapped = data.copy()
data_mapped['Language'] = data_mapped['Language'].map({'English':0, 'French':1, 'German':2})
data_mapped
# Out:
#      Country  Latitude  Longitude  Language
# 0        USA     44.97    -103.77         0
# 1     Canada     62.40     -96.80         0
# 2     France     46.75       2.40         1
# 3         UK     54.01      -2.53         0
# 4    Germany     51.15      10.40         2
# 5  Australia    -25.45     133.11         0

# %% [markdown]
# ## Select the features

# %%
x = data_mapped.iloc[:,1:4]
x
# Out:
#    Latitude  Longitude  Language
# 0     44.97    -103.77         0
# 1     62.40     -96.80         0
# 2     46.75       2.40         1
# 3     54.01      -2.53         0
# 4     51.15      10.40         2
# 5    -25.45     133.11         0

# %% [markdown]
# ## Clustering

# %%
kmeans = KMeans(2)

# %%
kmeans.fit(x)
# Out:
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %% [markdown]
# ## Clustering results

# %%
identified_clusters_1 = kmeans.fit_predict(x)
identified_clusters_1
# Out:
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([1, 1, 1, 1, 1, 0], dtype=int32)

# %%
data_with_clusters_1 = data.copy()
data_with_clusters_1['Cluster'] = identified_clusters_1
data_with_clusters_1
# Out:
#      Country  Latitude  Longitude Language  Cluster
# 0        USA     44.97    -103.77  English        1
# 1     Canada     62.40     -96.80  English        1
# 2     France     46.75       2.40   French        1
# 3         UK     54.01      -2.53  English        1
# 4    Germany     51.15      10.40   German        1
# 5  Australia    -25.45     133.11  English        0

# %%
plt.scatter(data_with_clusters_1['Longitude'], data_with_clusters_1['Latitude'], c=data_with_clusters_1['Cluster'], cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %%
kmeans.inertia_
# Out:
# 13208.958119999996

# %%
wcss = []
for i in range(1,7):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
# Out:
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# E:\python\data-science-bootcamp\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [42605.41356666667,
#  13208.958119999996,
#  290.10523333333333,
#  113.91233333333332,
#  42.17999999999999,
#  0.0]

# %% [markdown]
# ## The elbow methid

# %%
number_clusters = range(1,7)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')
